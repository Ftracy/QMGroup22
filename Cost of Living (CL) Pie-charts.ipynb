# %%
CL (Cost of Living) equation

CL = Rent/ month + Utilities/ month + Transportation/ day + Supermarket Cost/ week

# %%
We produced Hot Deck imputated data from Numbeo (2022) which is available as an Excel Workbook on our github repository:
https://github.com/Ftracy/QMGroup22/blob/main/Cost%20of%20Living%20(CL)%20Data.xlsx

# %%
We designed Pie Charts to show how the Cost of Living is split across the most expesive, affordable, average and central London borough.

# %%
# Pie Chart - Newham Cost of Living per Month - the most afforable borough 
# library
import matplotlib.pyplot as plt

#add chart title
plt.title("Newham Cost of Living per Month")

# create random data
names='Rent (£ 933.33)', 'Utilities (£ 48.19 )', 'Transport (£ 135)', 'Supermarket Cost (£ 159.72)',
values=[933.33, 48.19, 135, 159.72]
 
# Create a pieplot
plt.pie(size_of_groups)

# Create a set of colors
colors = ['#009900','#00e600', '#66ff66', '#b3ffb3'] #we use green colour to represent the most affordable borough to live in

# Use it thanks to the color argument
plt.pie(values, labels=names, labeldistance=1.15, wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, colors=colors);

# %%
# Pie Chart - Westminster Cost of Living per Month - the most expensive borough 
# library
import matplotlib.pyplot as plt

#add chart title
plt.title("Westminster Cost of Living per Month")

# create random data
names='Rent (£ 1968.57)', 'Utilities (£ 252.58 )', 'Transport (£ 168)', 'Supermarket Cost (£ 212.85)',
values=[1968.57, 252.58, 168, 212.85]
 
# Create a pieplot
plt.pie(size_of_groups)

# Create a set of colors
colors = ['#ff471a','#ff704d', '#ff8566', '#ffad99'] #we use red colour to represent the most expensive borough to live in

# Use it thanks to the color argument
plt.pie(values, labels=names, labeldistance=1.15, wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, colors=colors);

# %%
# Pie Chart - Haringey Cost of Living per Month - the average cost of living in boroughs 
# library
import matplotlib.pyplot as plt

#add chart title
plt.title("Haringey Cost of Living per Month")

# create random data
names='Rent (£ 1343.75)', 'Utilities (£ 204.33 )', 'Transport (£ 256.2)', 'Supermarket Cost (£ 136.32)',
values=[1343.75, 204.33, 256.2, 163.32]
 
# Create a pieplot
plt.pie(size_of_groups)

# Create a set of colors
colors = ['#ffaa00','#ffd480', '#ffff80', '#ffffb3'] #we use orange colour to represent the average cost to live in London boroughs

# Use it thanks to the color argument
plt.pie(values, labels=names, labeldistance=1.15, wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, colors=colors);

# %%
# Pie Chart - City of London Cost of Living per Month - the most central borough
# library
import matplotlib.pyplot as plt

#add chart title
plt.title("City of London Cost of Living per Month")

# create random data
names='Rent (£ 1744.23)', 'Utilities (£ 229.14)', 'Transport (£ 156)', 'Supermarket Cost (£ 176.28)',
values=[1744.23, 229.14, 156, 176.28]
 
# Create a pieplot
plt.pie(size_of_groups)

# Create a set of colors
colors = ['#135689','#19CCD7', '#42D5CD', '#8AE5D1']

# Use it thanks to the color argument
plt.pie(values, labels=names, labeldistance=1.15, wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, colors=colors);
