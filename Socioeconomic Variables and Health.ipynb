# %% [markdown]
# ## Step 1: Importing Libraries and Data

# %%
import pandas
pandas.__version__
# Out:
# '1.1.3'

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Downloads/Socio-Eco and BSh.csv")

# %%
data.head()
# Out:
#              Unnamed: 0    Income  Education  Race & Migration       BSh
# 0        City of London  0.157001   0.652974             0.710  0.889583
# 1  Barking and Dagenham  0.967799   1.000000             0.533  5.834483
# 2                Barnet  0.759254   0.050889             0.382  2.589319
# 3                Bexley  0.415499   0.587983             0.048  3.465013
# 4                 Brent  1.000000   0.671980             0.876  2.410352

# %%
df= data.drop(["Unnamed: 0"],axis=1)

df.head()
# Out:
#      Income  Education  Race & Migration       BSh
# 0  0.157001   0.652974             0.710  0.889583
# 1  0.967799   1.000000             0.533  5.834483
# 2  0.759254   0.050889             0.382  2.589319
# 3  0.415499   0.587983             0.048  3.465013
# 4  1.000000   0.671980             0.876  2.410352

# %% [markdown]
# ## Step 3: Visualising the Data
#
# Part 1) Here we will create a heatmap to show the correlation between the 3 socioeconomic variables we have chosen, and health status as a whole. The method to calculate 'BSh' using several indicators is outlined in the methdology section of our website.
#
# The numerical value in the centre of each square is the Pearson Correlation Co-efficient. The further away the value is from 0, the stronger relationship between the two variables. A positive value shows a positive correlation, whilst a negative value indicates a negative correlation
#
# Source for the Heatmap Guide: Waskom, a, 2022. seaborn.heatmap — seaborn 0.11.2 documentation. [online] Seaborn.pydata.org. Available at: https://seaborn.pydata.org/generated/seaborn.heatmap.html [Accessed 4 January 2022].

# %%
corr = df.corr(method='pearson')
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot=True)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0, 0.5, 'Income'),
#   Text(0, 1.5, 'Education'),
#   Text(0, 2.5, 'Race & Migration'),
#   Text(0, 3.5, 'BSh')])

# %% [markdown]
# Part 2) Now we will create a pairplot to visualise the relationships between these variables, the correlations for which are seen in the heatmap above. The diagonals in the pairplot show histograms to visualise the distribution of each variable's data.
#
# Source for the Pairplot Guide: Waskom, b, 2022. seaborn.pairplot — seaborn 0.11.2 documentation. [online] Seaborn.pydata.org. Available at: https://seaborn.pydata.org/generated/seaborn.pairplot.html [Accessed 6 January 2022].

# %%
sns.set_palette("Spectral", 12)
sns.pairplot(data, vars=["Income", "Education", "Race & Migration", "BSh"], kind="reg")
plt.show()
