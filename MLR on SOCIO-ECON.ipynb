# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('SOCIO-ECON.csv', encoding='latin1')
print("Size of dataset is : ", df.shape)
df
df_all_boroughs=df[['ï»¿Boroughs', 'Income', 'Education', 'Race&Migration', 'Health']]
df_all_boroughs= df_all_boroughs.rename(columns={'ï»¿Boroughs': 'Boroughs'})
df_all_boroughs
import sklearn
from sklearn import linear_model
X = df_all_boroughs[['Income', 'Education', 'Race&Migration']] 
# here we have 3 variables for multiple regression. 
# being Green Space Score, Air Pollution Score, and Noise Pollution Score
Y = df_all_boroughs['Health']
# health (health scores) are calcularted based on exisiting data via approahces discussed in the data methodology section
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y.astype(float),X.astype(float)).fit()
 
print_model = model.summary()
print(print_model)
#R square, coefficient, t value, P>t
#recording of last workshop, scatter graph of each variable
# Out:
#      <input type="file" id="files-3c0810ad-217d-4481-92ce-d68f5b50acc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c0810ad-217d-4481-92ce-d68f5b50acc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SOCIO-ECON.csv to SOCIO-ECON.csv
# Size of dataset is :  (33, 5)
# Intercept:
#  1.986847474548435
# Coefficients:
#  [ 1.14650664  2.07597041 -1.19571409]
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Health   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     5.213
# Date:                Sat, 08 Jan 2022   Prob (F-statistic):            0.00530
# Time:                        20:13:55   Log-Likelihood:                -38.855
# No. Observations:                  33   AIC:                             85.71
# Df Residuals:                      29   BIC:                             91.70
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              1.9868      0.422      4.706      0.000       1.123       2.850
# Income             1.1465      0.700      1.638      0.112      -0.285       2.578
# Education          2.0760      0.623      3.333      0.002       0.802       3.350
# Race&Migration    -1.1957      0.774     -1.545      0.133      -2.779       0.387
# ==============================================================================
# Omnibus:                        0.732   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.694   Jarque-Bera (JB):                0.757
# Skew:                          -0.314   Prob(JB):                        0.685
# Kurtosis:                       2.605   Cond. No.                         8.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
