# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('ENV.csv', encoding='latin1')
print("Size of dataset is : ", df.shape)
df
df_all_boroughs=df[['ï»¿Boroughs', 'Green Space Score', 'Air Pollution Score', 'Noise Pollution Score', 'Health']]
df_all_boroughs= df_all_boroughs.rename(columns={'ï»¿Boroughs': 'Boroughs'})
df_all_boroughs
import sklearn
from sklearn import linear_model
X = df_all_boroughs[['Green Space Score', 'Air Pollution Score', 'Noise Pollution Score']] 
# here we have 3 variables for multiple regression. 
# being Green Space Score, Air Pollution Score, and Noise Pollution Score
Y = df_all_boroughs['Health']
# health (health scores) are calcularted based on exisiting data via approahces discussed in the data methodology section
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y.astype(float),X.astype(float)).fit()
 
print_model = model.summary()
print(print_model)
#R square, coefficient, t value, P>t
#recording of last workshop, scatter graph of each variable
# Out:
#      <input type="file" id="files-92f65650-07e9-4017-b989-dcd1227ddc86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92f65650-07e9-4017-b989-dcd1227ddc86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ENV.csv to ENV (3).csv
# Size of dataset is :  (33, 11)
# Intercept:
#  3.579510682570074
# Coefficients:
#  [ 0.23313839 -0.46935955 -0.22350533]
#                             OLS Regression Results
# ...
# Dep. Variable:                 Health   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     1.862
# Date:                Tue, 04 Jan 2022   Prob (F-statistic):              0.158
# ...
