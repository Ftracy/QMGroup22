# %% [markdown]
# ## Step 1: Importing Libraries and Data

# %%
import pandas
pandas.__version__
# Out:
# '1.1.3'

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Downloads/BSh and BSe.csv")

# %%
data.head()
# Out:
#         BSh       Bse
# 0  5.834483  1.065821
# 1  2.589319  1.535078
# 2  3.465013  2.574994
# 3  2.410352  1.653081
# 4  2.416585  0.875597

# %% [markdown]
# #### (Our methods was calculating BSh and BSe have been outlined in our methodology section)

# %% [markdown]
# ## Step 2: Visualising the Data

# %% [markdown]
# #### As this data had already been cleaned and processed, we did not need to do anything further, before the visualisation stage

# %% [markdown]
# #### Here we will plot a linear regression with marginal distributions to visualise the correlation between BSh (overall health status of a borough) and Bse (overall environmental score of a borough).
#
# Source: Waskom, c, 2022. Linear regression with marginal distributions — seaborn 0.11.2 documentation. [online] Seaborn.pydata.org. Available at: https://seaborn.pydata.org/examples/regression_marginals.html [Accessed 6 January 2022].

# %%
g = sns.jointplot(y="BSh", x="Bse", data=data,
                  kind="reg", truncate=False,
                  xlim=(0, 6), ylim=(0, 6),
                  color="m", height=7)

# %% [markdown]
# #### This shows that there is a negative correlation between Bse and BSh. As Bse increases, BSh decreases; the less environmentally friendly a borough is, the better its health outcomes.
