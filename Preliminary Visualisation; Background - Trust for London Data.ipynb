# %% [markdown]
# ## Step 1: Importing Libraries and Data

# %%
import pandas
pandas.__version__
# Out:
# '1.1.3'

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Downloads/Life expectancy at birth by London borough (2017-19).csv")
data.head()
# Out:
#   Life expectancy at birth by borough for men and women (2017-19) Unnamed: 1  \
# 0                                                NaN                     NaN
# 1                                               Code                     Sex
# 2                                          E09000002                   Males
# 3                                          E09000002                 Females
# 4                                          E09000003                   Males
#
#              Unnamed: 2            Unnamed: 3                     Unnamed: 4
# 0                   NaN                   NaN                            NaN
# 1              Boroughs  Life Expectancy (LE)  Healthy Life Expectancy (HLE)
# 2  Barking and Dagenham                  78.1                           58.4
# 3  Barking and Dagenham                  82.3                           59.2
# 4                Barnet                  82.9                           61.8

# %% [markdown]
# ## Step 2: Creating a Data Frame

# %%
data= data.drop(["Life expectancy at birth by borough for men and women (2017-19)"],axis=1)

# %%
data= data.drop([0])

# %%
new_header = data.iloc[0]
data = data[1:] 
data.columns = new_header

# %%
data.head()
# Out:
# 1      Sex              Boroughs Life Expectancy (LE)  \
# 2    Males  Barking and Dagenham                 78.1
# 3  Females  Barking and Dagenham                 82.3
# 4    Males                Barnet                 82.9
# 5  Females                Barnet                   86
# 6    Males                Bexley                 80.1
#
# 1 Healthy Life Expectancy (HLE)
# 2                          58.4
# 3                          59.2
# 4                          61.8
# 5                          63.9
# 6                          66.5

# %%
type(78.1)
# Out:
# float

# %%
df = pd.DataFrame(data)
print (df)
print (df.dtypes)
# Out:
# 1       Sex              Boroughs Life Expectancy (LE)  \
# 2     Males  Barking and Dagenham                 78.1
# 3   Females  Barking and Dagenham                 82.3
# 4     Males                Barnet                 82.9
# 5   Females                Barnet                   86
# 6     Males                Bexley                 80.1
# ..      ...                   ...                  ...
# 68      NaN                   NaN                  NaN
# 69      NaN                   NaN                  NaN
# 70      NaN                   NaN                  NaN
# 71      NaN                   NaN                  NaN
# 72      NaN                   NaN                  NaN
#
# 1  Healthy Life Expectancy (HLE)
# 2                           58.4
# 3                           59.2
# 4                           61.8
# 5                           63.9
# 6                           66.5
# ..                           ...
# 68                           NaN
# 69                           NaN
# 70                           NaN
# 71                           NaN
# 72                           NaN
#
# [71 rows x 4 columns]
# 1
# Sex                              object
# Boroughs                         object
# Life Expectancy (LE)             object
# Healthy Life Expectancy (HLE)    object
# dtype: object

# %% [markdown]
# ### ^^ Here it is important to note that the values for Life Expectancy and Healthy Life Expectancy appear as 'objects'. In order to plot/graph the data, these values need to be recognised as numerical

# %%
df = pd.DataFrame(data)
df['Life Expectancy (LE)'] = pd.to_numeric(df['Life Expectancy (LE)'])
df['Healthy Life Expectancy (HLE)'] = pd.to_numeric(df['Healthy Life Expectancy (HLE)'])

print (df)
print (df.dtypes)
# Out:
# 1       Sex              Boroughs  Life Expectancy (LE)  \
# 2     Males  Barking and Dagenham                  78.1
# 3   Females  Barking and Dagenham                  82.3
# 4     Males                Barnet                  82.9
# 5   Females                Barnet                  86.0
# 6     Males                Bexley                  80.1
# ..      ...                   ...                   ...
# 68      NaN                   NaN                   NaN
# 69      NaN                   NaN                   NaN
# 70      NaN                   NaN                   NaN
# 71      NaN                   NaN                   NaN
# 72      NaN                   NaN                   NaN
#
# 1   Healthy Life Expectancy (HLE)
# 2                            58.4
# 3                            59.2
# 4                            61.8
# 5                            63.9
# 6                            66.5
# ..                            ...
# 68                            NaN
# 69                            NaN
# 70                            NaN
# 71                            NaN
# 72                            NaN
#
# [71 rows x 4 columns]
# 1
# Sex                               object
# Boroughs                          object
# Life Expectancy (LE)             float64
# Healthy Life Expectancy (HLE)    float64
# dtype: object

# %% [markdown]
# ### Now the values for Life Expectancy and Healthy Life Expectancy are recognised as 'floats'

# %% [markdown]
# ## Step 3: Visualising the Distribution of this Data

# %%
ax = sns.boxplot(x="Sex", y="Life Expectancy (LE)", data=data, whis=np.inf, palette="PuBuGn")
ax = sns.stripplot(x="Sex", y="Life Expectancy (LE)", data=data, color=".3")

# %%
ax = sns.boxplot(x="Sex", y="Healthy Life Expectancy (HLE)", data=data, whis=np.inf, palette="PuBuGn")
ax = sns.stripplot(x="Sex", y="Healthy Life Expectancy (HLE)", data=data, color=".3")

# %%
ax = sns.boxplot(x="Life Expectancy (LE)", data=data, palette="PuBuGn")
ax = sns.stripplot(x="Life Expectancy (LE)", data=data, color=".3")

# %%
ax = sns.boxplot(x="Healthy Life Expectancy (HLE)", data=data, palette="PuBuGn")
ax = sns.stripplot(x="Healthy Life Expectancy (HLE)", data=data, color=".3")

# %%
sns.violinplot(y="Life Expectancy (LE)", x="Sex", data=data, palette="Set2")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Life Expectancy (LE)'>

# %%
sns.violinplot(y="Healthy Life Expectancy (HLE)", x="Sex", data=data, palette="Set2")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Healthy Life Expectancy (HLE)'>

# %%
sns.violinplot(y="Life Expectancy (LE)", data=data, palette="Set2")
# Out:
# <AxesSubplot:ylabel='Life Expectancy (LE)'>

# %%
sns.violinplot(y="Healthy Life Expectancy (HLE)", data=data, palette="Set2")
# Out:
# <AxesSubplot:ylabel='Healthy Life Expectancy (HLE)'>
